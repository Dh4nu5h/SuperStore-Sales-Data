# %%
import numpy as np #linear algebra
import pandas as pd #data preprocessing
import seaborn as sns

# %%
import matplotlib.pyplot as plt #data visualizaiton
df = pd.read_csv("/content/train.csv")

# %% [markdown]
# ***1. Data Exploration***

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# 0      42420.0  South  FUR-BO-10001798        Furniture    Bookcases
# 1      42420.0  South  FUR-CH-10000454        Furniture       Chairs
# 2      90036.0   West  OFF-LA-10000240  Office Supplies       Labels
# 3      33311.0  South  FUR-TA-10000577        Furniture       Tables
# 4      33311.0  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales
# 0                  Bush Somerset Collection Bookcase  261.9600
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4                     Eldon Fold 'N Roll Cart System   22.3680

# %%
#Removing unnecessary columns
df.drop(columns=["Row ID", "Order ID", "Customer ID", "Country", "Product ID", "Product Name", "Customer Name","Postal Code"], axis = 1, inplace = True)

# %%
#Amount of sales per category
df["Category"].value_counts()
# Out:
# Category
# Office Supplies    5909
# Furniture          2078
# Technology         1813
# Name: count, dtype: int64

# %%
plt.hist(df.Category, bins=5, rwidth=1.0, color="g")
plt.title("Categories")
plt.ylabel("Amount of Orders")
plt.grid(axis="y", alpha=0.75);

# %%
df.City.nunique()
# Out:
# 529

# %%
df.drop(columns = ["City", "Region"], inplace = True)

# %% [markdown]
# ***2. Tempopral Analysis***

# %%
#Fixing Dates for easy understanding
df["Order Date"] = pd.to_datetime(df["Order Date"], format = "%d/%m/%Y")
df["Ship Date"] = pd.to_datetime(df["Ship Date"], format = "%d/%m/%Y")

df['Month_order'] = df['Order Date'].dt.to_period('M')

df['Year_order'] = df['Order Date'].dt.to_period('Y')

# %%
# Monthly Sales Analysis
monthSalesByCategory = df.groupby(["Month_order", "Category"])["Sales"].sum().unstack()

# %%
monthSalesByCategory.plot(kind="line", marker="o", figsize=(15, 8))
plt.title("Monthly sales by category ", fontsize=14)
plt.xlabel("Month", fontsize=12)
plt.ylabel("Total Sales", fontsize=12)
plt.grid(True, linestyle="--", alpha=0.6)
plt.legend(title="Category", fontsize=12)
plt.tight_layout()

# %%
# Yearly Sales Analysis
yearlyOrder = df.groupby(["Year_order", "Category"])["Sales"].sum().unstack()
yearlyOrder.plot(kind="line", marker="o", figsize=(15, 8))
plt.title("yearly sales by category", fontsize=14)
plt.xlabel("year", fontsize=12)
plt.ylabel("total sales", fontsize=12)
plt.grid(True, linestyle="--", alpha=0.6)
plt.legend(title="Category", fontsize=12)
plt.tight_layout()

# %%
# Analysis of Top 30 States by Revenue
salesState = df.groupby("State")["Sales"].sum()
salesState = salesState.sort_values(ascending=False).head(30)
plt.figure(figsize=(14, 8))
salesState.plot(kind='bar', color='skyblue')
plt.title('Top revenue states')
plt.xlabel('State')
plt.ylabel('Total sales')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
total_sales = salesState.sum()
percentagePerState = salesState / total_sales * 100
percentagePerState
# Out:
# State
# California        20.707678
# New York          14.214511
# Texas              7.821410
# Washington         6.273312
# Pennsylvania       5.394991
# Florida            4.103268
# Illinois           3.676407
# Michigan           3.532553
# Ohio               3.485890
# Virginia           3.277395
# North Carolina     2.559584
# Indiana            2.260431
# Georgia            2.237265
# Kentucky           1.691592
# Arizona            1.636577
# New Jersey         1.605876
# Colorado           1.477383
# Wisconsin          1.446381
# Tennessee          1.422646
# Minnesota          1.385587
# Massachusetts      1.328577
# Delaware           1.267729
# Maryland           1.099886
# Rhode Island       1.045114
# Missouri           1.030272
# Oklahoma           0.913268
# Alabama            0.905253
# Oregon             0.801963
# Nevada             0.776195
# Connecticut        0.621006
# Name: Sales, dtype: float64

# %% [markdown]
# ***3. Outliers and Correlation***

# %%
# Outliers shown in boxplot
sns.boxplot(x='Category', y='Sales', data=df)
plt.show()

# %%
# Clean up outliers using the interquartile range
column = "Sales"
Q1 = df[column].quantile(0.25)
Q3 = df[column].quantile(0.75)

IQR = Q3 - Q1

inf_lim = Q1 - 1.5 * IQR
sup_lim = Q3 + 1.5 * IQR

# %%
# Cleaned dataframe boxplot
df_clean = df[(df[column] >= inf_lim) & (df[column] <= sup_lim)].copy()
sns.boxplot(x='Category', y='Sales', data=df_clean)
plt.show()

# %%
df_clean.apply(lambda x: x.nunique())
# Out:
# Order Date      1217
# Ship Date       1309
# Ship Mode          4
# Segment            3
# State             48
# Category           3
# Sub-Category      17
# Sales           4831
# Month_order       48
# Year_order         4
# dtype: int64

# %%
# Turn the dates from periods to float for the correlation matrix

df_clean['Year_order'] = df_clean['Order Date'].dt.year
df_clean['Month_order'] = df_clean['Order Date'].dt.month
df_clean.drop(columns=["Order Date", "Ship Date"], inplace=True)


df_encoded = pd.get_dummies(df_clean, drop_first=True)

# %%
print(df_encoded)
# Out:
#         Sales  Month_order  Year_order  Ship Mode_Same Day  \
# 0     261.960           11        2017               False
# 2      14.620            6        2017               False
# 4      22.368           10        2016               False
# 5      48.860            6        2015               False
# 6       7.280            6        2015               False
# ...       ...          ...         ...                 ...
# 9795    3.798            5        2017               False
# 9796   10.368            1        2016               False
# 9797  235.188            1        2016               False
# 9798   26.376            1        2016               False
# 9799   10.384            1        2016               False
#
#       Ship Mode_Second Class  Ship Mode_Standard Class  Segment_Corporate  \
# 0                       True                     False              False
# 2                       True                     False               True
# 4                      False                      True              False
# 5                      False                      True              False
# 6                      False                      True              False
# ...                      ...                       ...                ...
# 9795                   False                      True               True
# 9796                   False                      True               True
# 9797                   False                      True               True
# 9798                   False                      True               True
# 9799                   False                      True               True
#
#       Segment_Home Office  State_Arizona  State_Arkansas  ...  \
# 0                   False          False           False  ...
# 2                   False          False           False  ...
# 4                   False          False           False  ...
# 5                   False          False           False  ...
# 6                   False          False           False  ...
# ...                   ...            ...             ...  ...
# 9795                False          False           False  ...
# 9796                False          False           False  ...
# 9797                False          False           False  ...
# 9798                False          False           False  ...
# 9799                False          False           False  ...
#
#       Sub-Category_Envelopes  Sub-Category_Fasteners  \
# 0                      False                   False
# 2                      False                   False
# 4                      False                   False
# 5                      False                   False
# 6                      False                   False
# ...                      ...                     ...
# 9795                   False                   False
# 9796                   False                   False
# 9797                   False                   False
# 9798                   False                   False
# 9799                   False                   False
#
#       Sub-Category_Furnishings  Sub-Category_Labels  Sub-Category_Machines  \
# 0                        False                False                  False
# 2                        False                 True                  False
# 4                        False                False                  False
# 5                         True                False                  False
# 6                        False                False                  False
# ...                        ...                  ...                    ...
# 9795                     False                False                  False
# 9796                     False                False                  False
# 9797                     False                False                  False
# 9798                     False                False                  False
# 9799                     False                False                  False
#
#       Sub-Category_Paper  Sub-Category_Phones  Sub-Category_Storage  \
# 0                  False                False                 False
# 2                  False                False                 False
# 4                  False                False                  True
# 5                  False                False                 False
# 6                  False                False                 False
# ...                  ...                  ...                   ...
# 9795               False                False                 False
# 9796               False                False                 False
# 9797               False                 True                 False
# 9798               False                 True                 False
# 9799               False                False                 False
#
#       Sub-Category_Supplies  Sub-Category_Tables
# 0                     False                False
# 2                     False                False
# 4                     False                False
# 5                     False                False
# 6                     False                False
# ...                     ...                  ...
# 9795                  False                False
# 9796                  False                False
# 9797                  False                False
# 9798                  False                False
# 9799                  False                False
#
# [8655 rows x 73 columns]

# %%
correlation_matrix = df_encoded.corr()
correlation_matrix.describe()
# Out:
#            Sales  Month_order  Year_order  Ship Mode_Same Day  \
# count  73.000000    73.000000   73.000000           73.000000
# mean    0.017161     0.011347    0.013396            0.006846
# std     0.146850     0.118680    0.118270            0.124474
# min    -0.391760    -0.045786   -0.051662           -0.293978
# 25%    -0.012998    -0.014532   -0.012994           -0.010365
# 50%     0.001777     0.001255    0.001234           -0.004477
# 75%     0.013901     0.009655    0.010224            0.008941
# max     1.000000     1.000000    1.000000            1.000000
#
#        Ship Mode_Second Class  Ship Mode_Standard Class  Segment_Corporate  \
# count               73.000000                 73.000000          73.000000
# mean                 0.004565                  0.001895           0.009708
# std                  0.139084                  0.142708           0.123731
# min                 -0.598068                 -0.598068          -0.302155
# 25%                 -0.011651                 -0.009565          -0.011792
# 50%                  0.001003                  0.002777           0.000614
# 75%                  0.007606                  0.013505           0.011060
# max                  1.000000                  1.000000           1.000000
#
#        Segment_Home Office  State_Arizona  State_Arkansas  ...  \
# count            73.000000      73.000000       73.000000  ...
# mean              0.011847       0.001874        0.007104  ...
# std               0.123669       0.119577        0.118159  ...
# min              -0.302155      -0.077758       -0.038992  ...
# 25%              -0.008030      -0.018084       -0.010909  ...
# 50%               0.002850      -0.010117       -0.005841  ...
# 75%               0.015129      -0.002915       -0.002388  ...
# max               1.000000       1.000000        1.000000  ...
#
#        Sub-Category_Envelopes  Sub-Category_Fasteners  \
# count               73.000000               73.000000
# mean                 0.005651                0.005408
# std                  0.121164                0.121305
# min                 -0.075900               -0.109937
# 25%                 -0.017171               -0.012849
# 50%                 -0.005213               -0.005343
# 75%                  0.004962                0.006234
# max                  1.000000                1.000000
#
#        Sub-Category_Furnishings  Sub-Category_Labels  Sub-Category_Machines  \
# count                 73.000000            73.000000              73.000000
# mean                  -0.010741             0.002728               0.011686
# std                    0.136548             0.123102               0.120795
# min                   -0.463509            -0.112558              -0.103650
# 25%                   -0.017523            -0.015670              -0.010249
# 50%                   -0.003836            -0.005447              -0.004020
# 75%                    0.005522             0.003908               0.000391
# max                    1.000000             1.000000               1.000000
#
#        Sub-Category_Paper  Sub-Category_Phones  Sub-Category_Storage  \
# count           73.000000            73.000000             73.000000
# mean            -0.003694             0.006928              0.002524
# std              0.135110             0.153796              0.127123
# min             -0.189032            -0.393237             -0.130749
# 25%             -0.020181            -0.012749             -0.015453
# 50%             -0.001895            -0.005385             -0.005498
# 75%              0.009242             0.008567              0.004736
# max              1.000000             1.000000              1.000000
#
#        Sub-Category_Supplies  Sub-Category_Tables
# count              73.000000            73.000000
# mean                0.006535             0.005400
# std                 0.120066             0.123928
# min                -0.062682            -0.191889
# 25%                -0.011111            -0.012257
# 50%                -0.004447            -0.005719
# 75%                 0.004841             0.001653
# max                 1.000000             1.000000
#
# [8 rows x 73 columns]

# %%
# Only positive correlations
positiveCorrelation = correlation_matrix[correlation_matrix > 0]
positiveCorrelation.describe()
# Out:
#            Sales  Month_order  Year_order  Ship Mode_Same Day  \
# count  39.000000    37.000000   39.000000           29.000000
# mean    0.071699     0.038389    0.037282            0.047808
# std     0.169901     0.162807    0.158552            0.183501
# min     0.001138     0.001255    0.000058            0.001153
# 25%     0.005940     0.003159    0.003885            0.006262
# 50%     0.012974     0.009655    0.009011            0.011788
# 75%     0.038039     0.016830    0.018326            0.020444
# max     1.000000     1.000000    1.000000            1.000000
#
#        Ship Mode_Second Class  Ship Mode_Standard Class  Segment_Corporate  \
# count               38.000000                 41.000000          40.000000
# mean                 0.039658                  0.036679           0.036009
# std                  0.160601                  0.154444           0.156603
# min                  0.000336                  0.000099           0.000024
# 25%                  0.003586                  0.005567           0.004078
# 50%                  0.007578                  0.012310           0.010523
# 75%                  0.020476                  0.020043           0.018256
# max                  1.000000                  1.000000           1.000000
#
#        Segment_Home Office  State_Arizona  State_Arkansas  ...  \
# count            40.000000      15.000000       10.000000  ...
# mean              0.039067       0.075020        0.107500  ...
# std               0.156185       0.255918        0.313640  ...
# min               0.000273       0.003714        0.000734  ...
# 25%               0.006886       0.006249        0.005013  ...
# 50%               0.010422       0.008736        0.007293  ...
# 75%               0.022022       0.011537        0.015093  ...
# max               1.000000       1.000000        1.000000  ...
#
#        Sub-Category_Envelopes  Sub-Category_Fasteners  \
# count               28.000000               28.000000
# mean                 0.048770                0.048254
# std                  0.187853                0.187749
# min                  0.000329                0.000519
# 25%                  0.004140                0.005022
# 50%                  0.006515                0.007728
# 75%                  0.017590                0.014136
# max                  1.000000                1.000000
#
#        Sub-Category_Furnishings  Sub-Category_Labels  Sub-Category_Machines  \
# count                 28.000000            28.000000              20.000000
# mean                   0.043267             0.048377               0.071042
# std                    0.187587             0.188585               0.222619
# min                    0.000099             0.000037               0.000126
# 25%                    0.004210             0.002516               0.003821
# 50%                    0.008189             0.007014               0.007879
# 75%                    0.011577             0.014310               0.018824
# max                    1.000000             1.000000               1.000000
#
#        Sub-Category_Paper  Sub-Category_Phones  Sub-Category_Storage  \
# count           31.000000            29.000000             28.000000
# mean             0.052730             0.071984              0.055737
# std              0.184164             0.217183              0.190052
# min              0.000024             0.000765              0.000611
# 25%              0.005574             0.005071              0.003451
# 50%              0.009990             0.009562              0.009233
# 75%              0.017276             0.014186              0.015827
# max              1.000000             1.000000              1.000000
#
#        Sub-Category_Supplies  Sub-Category_Tables
# count              24.000000            21.000000
# mean                0.053197             0.065541
# std                 0.202690             0.218495
# min                 0.000871             0.000273
# 25%                 0.005298             0.003252
# 50%                 0.006483             0.010557
# 75%                 0.010038             0.016167
# max                 1.000000             1.000000
#
# [8 rows x 73 columns]
